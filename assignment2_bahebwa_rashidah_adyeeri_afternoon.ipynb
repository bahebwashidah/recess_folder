# %%
import pandas as pd

# Define the sample series
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

# Compare the elements of the two series
comparison = series1 == series2

# Display the comparison result
print(comparison)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
import pandas as pd

# Define the sample series
series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

# Addition
addition = series1 + series2
print("Addition:")
print(addition)

# Subtraction
subtraction = series1 - series2
print("\nSubtraction:")
print(subtraction)

# Multiplication
multiplication = series1 * series2
print("\nMultiplication:")
print(multiplication)

# Division
division = series1 / series2
print("\nDivision:")
print(division)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %%
import pandas as pd

# Define the sample dictionary
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

# Convert dictionary to Series
series1 = pd.Series(dictionary1)

# Display the converted Series
print(series1)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Define the sample series
series1 = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

# Convert series to array
array1 = np.array(series1)

# Display the converted array
print(array1)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %%
import pandas as pd

# Specify the file path of the dataset
file_path = 'C:\\Users\\user\\Desktop\\learn python\\Exercise Python\\BSSE 2301 EXERCISE 2\\AfricaCupofNationsMatches.csv'  # Update with the actual file path and name

# Read the dataset using pandas
df = pd.read_csv(file_path)

# Display the first few rows of the dataset

# Assuming you have a DataFrame named 'df' containing your data

# Get the first 7 rows of the DataFrame
first_7_rows = df.head(7)

# Display the first 7 rows
print(first_7_rows)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
# Assuming you have a DataFrame named 'df' containing your data

# Select specific columns
selected_columns = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]

# Display the selected columns
print(selected_columns)
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %%
# Assuming you have a DataFrame named 'df' containing your data

# Select rows where 'Egypt' appears in a specific column
egypt_rows = df[df['HomeTeam'] == 'Egypt']  # Replace 'Country' with the actual column name

# Display the selected rows
print(egypt_rows)
# Out:
#     Year      Date  Time  HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN    Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN    Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN    Egypt     Uganda            2.0            1.0
# 13  1963  24-Nov-63   NaN    Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN    Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN    Egypt   Ethiopia            3.0            0.0
#
#                 Stage SpecialWinConditions                 Stadium  \
# 3    Final Tournament                  NaN   Prince Farouk Stadium
# 5    Final Tournament                  NaN   Prince Farouk Stadium
# 7          Semifinals                  NaN  Hailé Sélassié Stadium
# 13            Group B                  NaN   Kumasi Sports Stadium
# 14            Group B                  NaN   Kumasi Sports Stadium
# ...

# %%
# Count the number of rows and columns
num_rows, num_columns = df.shape

# Display the counts
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 622
# Number of columns: 12

# %%
# Select rows where 'Attendance' is missing
missing_attendance_rows = df[df['Attendance'].isnull()]

# Display the selected rows
print(missing_attendance_rows)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %%
# Select rows where 'HomeTeamGoals' are between 3 and 6 (inclusive)
selected_rows = df[df['HomeTeamGoals'].between(3, 6)]

# Display the selected rows
print(selected_rows)
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %%
# Change the value of "AwayTeamGoals" in the 3rd row to 10
df.at[2, 'AwayTeamGoals'] = 10

# Display the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# Sort the DataFrame by 'HomeTeam' in ascending order
sorted_df = df.sort_values('HomeTeam')

# Display the sorted DataFrame
print(sorted_df)
# Out:
#      Year                         Date   Time    HomeTeam   AwayTeam  \
# 403  2004                      3-Feb-04  14:00   Algeria    Zimbabwe
# 229  1992                     17-Jan-92    NaN   Algeria       Congo
# 291  1998                      8-Feb-98  20:30   Algeria      Guinea
# 544  2017  15 January 2017 (2017-01-15)  17:00   Algeria    Zimbabwe
# 148  1982                      7-Mar-82    NaN   Algeria      Zambia
# ..    ...                           ...    ...        ...        ...
# 230  1992                     13-Jan-92    NaN    Zambia       Egypt
# 575  2019     30 June 2019 (2019-06-30)  21:00  Zimbabwe    DR Congo
# 437  2006                     23-Jan-06  20:00  Zimbabwe     Senegal
# 549  2017  23 January 2017 (2017-01-23)  20:00  Zimbabwe     Tunisia
# 398  2004                     25-Jan-04  16:30  Zimbabwe       Egypt
#
#      HomeTeamGoals  AwayTeamGoals    Stage SpecialWinConditions  \
# 403            1.0            2.0  Group C                  NaN
# ...

# %%
# Sort the DataFrame by 'HomeTeamScores' in descending order
sorted_df = df.sort_values('HomeTeamGoals', ascending=False)

# Display the sorted DataFrame
print(sorted_df)
# Out:
#      Year                      Date   Time        HomeTeam  \
# 13   1963                  24-Nov-63    NaN          Egypt
# 46   1970                  10-Feb-70    NaN   Ivory Coast
# 72   1972                   4-Mar-72    NaN      Cameroon
# 21   1965                  12-Nov-65    NaN         Ghana
# 400  2004                  29-Jan-04  16:30      Cameroon
# ..    ...                        ...    ...            ...
# 621  2019  19 July 2019 (2019-07-19)  21:00       Senegal
# 1    1957                  10-Feb-57    NaN      Ethiopia
# 489  2010                  11-Jan-10  19:30         Ghana
# 490  2010                  15-Jan-10  17:00  Burkina Faso
# 493  2010                  19-Jan-10  17:00   Ivory Coast
#
#                  AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 13                Nigeria            6.0            3.0            Group B
# 46               Ethiopia            6.0            1.0            Group A
# ...

# %%
# Get list of column headers
column_headers = df.columns.tolist()

# Display the list of column headers
print(column_headers)
# Out:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance', 'NewColumn', 'Position ']

# %%
# Create a new column with values matching the size of the DataFrame
new_column = ['English '] * len(df)

# Append the new column to the DataFrame
df['language   '] = new_column

# Display the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# Create dictionaries representing the new rows
new_row1 = {'HomeTeam': 'Team A', 'AwayTeam': 'Team B', 'HomeTeamGoals': 2, 'AwayTeamGoals': 1}
new_row2 = {'HomeTeam': 'Team C', 'AwayTeam': 'Team D', 'HomeTeamGoals': 3, 'AwayTeamGoals': 2}

# Create DataFrames for the new rows
df_row1 = pd.DataFrame(new_row1, index=[0])
df_row2 = pd.DataFrame(new_row2, index=[0])

# Concatenate the new rows with the original DataFrame
df = pd.concat([df, df_row1, df_row2], ignore_index=True)

# Display the updated DataFrame
print(df)
# Out:
#        Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1    1957.0  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2    1957.0  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3    1959.0  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4    1959.0  25-May-59   NaN     Sudan        Ethiopia            1.0
# ..      ...        ...   ...        ...            ...            ...
# 623     NaN        NaN   NaN     Team C         Team D            3.0
# 624     NaN        NaN   NaN     Team A         Team B            2.0
# 625     NaN        NaN   NaN     Team C         Team D            3.0
# 626     NaN        NaN   NaN     Team A         Team B            2.0
# 627     NaN        NaN   NaN     Team C         Team D            3.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# 1              NaN        Semifinals
# ...

# %%
# Change 'Uganda' to 'China' in the 'AwayTeam' column
df.loc[df['AwayTeam'] == 'Uganda', 'AwayTeam'] = 'China'

# Display the updated DataFrame
print(df)
# Out:
#        Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1    1957.0  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2    1957.0  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3    1959.0  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4    1959.0  25-May-59   NaN     Sudan        Ethiopia            1.0
# ..      ...        ...   ...        ...            ...            ...
# 623     NaN        NaN   NaN     Team C         Team D            3.0
# 624     NaN        NaN   NaN     Team A         Team B            2.0
# 625     NaN        NaN   NaN     Team C         Team D            3.0
# 626     NaN        NaN   NaN     Team A         Team B            2.0
# 627     NaN        NaN   NaN     Team C         Team D            3.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# 1              NaN        Semifinals
# ...

# %%
# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# Display the DataFrame with the reset index
print(df)
# Out:
#        Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1    1957.0  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2    1957.0  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3    1959.0  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4    1959.0  25-May-59   NaN     Sudan        Ethiopia            1.0
# ..      ...        ...   ...        ...            ...            ...
# 623     NaN        NaN   NaN     Team C         Team D            3.0
# 624     NaN        NaN   NaN     Team A         Team B            2.0
# 625     NaN        NaN   NaN     Team C         Team D            3.0
# 626     NaN        NaN   NaN     Team A         Team B            2.0
# 627     NaN        NaN   NaN     Team C         Team D            3.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# 1              NaN        Semifinals
# ...

# %%
# Check if 'Stadium' column is present in the DataFrame
if 'Stadium' in df.columns:
    print("'Stadium' column is present")
else:
    print("'Stadium' column is not present")
# Out:
# 'Stadium' column is present

# %%
# Convert the data type of 'AwayTeamGoals' column to float
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

# Display the updated DataFrame with the converted data type
print(df)
# Out:
#        Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1    1957.0  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2    1957.0  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3    1959.0  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4    1959.0  25-May-59   NaN     Sudan        Ethiopia            1.0
# ..      ...        ...   ...        ...            ...            ...
# 623     NaN        NaN   NaN     Team C         Team D            3.0
# 624     NaN        NaN   NaN     Team A         Team B            2.0
# 625     NaN        NaN   NaN     Team C         Team D            3.0
# 626     NaN        NaN   NaN     Team A         Team B            2.0
# 627     NaN        NaN   NaN     Team C         Team D            3.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# 1              NaN        Semifinals
# ...

# %%
# Remove the last 10 rows from the DataFrame
df = df.iloc[:-10]

# Display the updated DataFrame
print(df)
# Out:
#        Year                      Date   Time       HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN        Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN     Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN        Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN         Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN        Sudan        Ethiopia
# ..      ...                        ...    ...           ...            ...
# 613  2019.0   8 July 2019 (2019-07-08)  21:00        Ghana         Tunisia
# 614  2019.0  10 July 2019 (2019-07-10)  18:00      Senegal           Benin
# 615  2019.0  10 July 2019 (2019-07-10)  21:00      Nigeria    South Africa
# 616  2019.0  11 July 2019 (2019-07-11)  18:00  Ivory Coast         Algeria
# 617  2019.0  11 July 2019 (2019-07-11)  21:00   Madagascar         Tunisia
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# ...

# %%
# Iterate over rows in the DataFrame
for index, row in df.iterrows():
    # Access row data using row[column_name]
    print("Row index:", index)'])
    print("HomeTeamGoals:", row['HomeTeamGoals'])
    print("AwayTeamGoals:", row['AwayTeamGoals'])
    print("--------------------")

    print("Column values:")
    print("HomeTeam:", row['HomeTeam'])
    print("AwayTeam:", row['AwayTeam
# Out:
# Row index: 0
# Column values:
# HomeTeam: Sudan
# AwayTeam:  Egypt
# HomeTeamGoals: 1.0
# AwayTeamGoals: 2.0
# --------------------
# Row index: 1
# Column values:
# HomeTeam: Ethiopia
# AwayTeam:  South Africa
# HomeTeamGoals: nan
# AwayTeamGoals: nan
# --------------------
# Row index: 2
# Column values:
# HomeTeam: Egypt
# AwayTeam:  Ethiopia
# HomeTeamGoals: 4.0
# AwayTeamGoals: 10.0
# --------------------
# Row index: 3
# Column values:
# HomeTeam: Egypt
# AwayTeam:  Ethiopia
# HomeTeamGoals: 4.0
# AwayTeamGoals: 0.0
# --------------------
# Row index: 4
# Column values:
# HomeTeam: Sudan
# AwayTeam:  Ethiopia
# HomeTeamGoals: 1.0
# AwayTeamGoals: 0.0
# --------------------
# Row index: 5
# Column values:
# HomeTeam: Egypt
# AwayTeam:  Sudan
# HomeTeamGoals: 2.0
# AwayTeamGoals: 1.0
# --------------------
# Row index: 6
# Column values:
# HomeTeam: Ethiopia
# AwayTeam:  Tunisia
# HomeTeamGoals: 4.0
# AwayTeamGoals: 2.0
# --------------------
# Row index: 7
# Column values:
# ...

# %%
# Define the desired column order
desired_columns = ['HomeTeam', 'HomeTeamGoals', 'AwayTeam']

# Reorder the DataFrame columns
df = df[desired_columns]

# Display the updated DataFrame with the changed column order
print(df)
# Out:
#          HomeTeam  HomeTeamGoals       AwayTeam
# 0          Sudan             1.0          Egypt
# 1       Ethiopia             NaN   South Africa
# 2          Egypt             4.0       Ethiopia
# 3           Egypt            4.0       Ethiopia
# 4          Sudan             1.0       Ethiopia
# ..            ...            ...            ...
# 613        Ghana             1.0        Tunisia
# 614      Senegal             1.0          Benin
# 615      Nigeria             2.0   South Africa
# 616  Ivory Coast             1.0        Algeria
# 617   Madagascar             0.0        Tunisia
#
# [618 rows x 3 columns]

# %%
# Delete rows where 'HomeTeamGoals' is 0
df = df[df['HomeTeamGoals'] != 0]

# Display the updated DataFrame
print(df)
# Out:
#          HomeTeam  HomeTeamGoals       AwayTeam
# 0          Sudan             1.0          Egypt
# 1       Ethiopia             NaN   South Africa
# 2          Egypt             4.0       Ethiopia
# 3           Egypt            4.0       Ethiopia
# 4          Sudan             1.0       Ethiopia
# ..            ...            ...            ...
# 611      Algeria             3.0         Guinea
# 613        Ghana             1.0        Tunisia
# 614      Senegal             1.0          Benin
# 615      Nigeria             2.0   South Africa
# 616  Ivory Coast             1.0        Algeria
#
# [492 rows x 3 columns]

# %%
#QUESTION 5 ABOUT SERIES
# Access the 'HomeTeamGoals' column from the DataFrame
series = df['HomeTeamGoals']

# Find the most frequent value in the Series
most_frequent_value = series.value_counts().idxmax()

# Replace everything else as 'Other'
series[series != most_frequent_value] = 'Other'

# Display the updated Series
print(series)
# Out:
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 611    Other
# 613      1.0
# 614      1.0
# 615    Other
# 616      1.0
# Name: HomeTeamGoals, Length: 492, dtype: object
